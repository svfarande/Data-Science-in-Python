# %% [markdown]
# ### Basics of Statistical Testing in Python
# **Hypothesis Testing**
#
# When we do hypothesis testing, we actually have two statements of interest: the first is our actual explanation, which we call the alternative hypothesis, and the second is that the explanation we have is not sufficient, and we call this the null hypothesis. Our actual testing method is to determine whether the null hypothesis is true or not. If we find that there is a difference between groups, then we can reject the null hypothesis and we accept our alternative.

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
df=pd.read_csv ('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 4  2015-12-14 12:25:12.056000000          41.932832
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 4  2015-12-29 14:25:22.594000000          36.929549
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 4  2015-12-28 01:29:55.901000000          33.236594
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 4  2015-12-29 14:46:06.628000000          33.236594
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 4  2016-01-05 01:06:59.546000000

# %%
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 columns

# %%
early_finishers = df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# 8  2015-12-31 01:42:30.046000000          48.344809
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 4  2015-12-29 14:25:22.594000000          36.929549
# 5  2016-01-07 08:55:43.692000000          57.467295
# 8  2016-01-05 23:34:02.180000000          47.444809
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 4  2015-12-28 01:29:55.901000000          33.236594
# 5  2016-01-11 00:45:28.706000000          57.467295
# 8  2016-01-02 07:48:42.517000000          37.955847
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 4  2015-12-29 14:46:06.628000000          33.236594
# 5  2016-01-11 00:54:13.579000000          57.467295
# 8  2016-01-03 21:27:04.266000000          37.955847
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 4  2016-01-05 01:06:59.546000000
# 5  2016-01-20 19:54:46.166000000
# 8  2016-01-19 15:24:31.060000000

# %%
early_finishers.shape
# Out:
# (1259, 13)

# %%
late_finishers = df[~(pd.to_datetime(df['assignment1_submission']) < '2016')]
# late_finishers = df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# 9  2016-03-13 02:07:25.289000000          53.343794
#
#           assignment3_submission  assignment4_grade  \
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 6  2016-03-16 22:31:24.316000000          50.399276
# 7  2016-01-30 14:34:36.581000000          65.266633
# 9  2016-03-17 07:30:09.241000000          53.343794
#
#           assignment4_submission  assignment5_grade  \
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 6  2016-03-18 07:19:26.032000000          45.359349
# 7  2016-02-03 22:08:49.002000000          65.266633
# 9  2016-03-20 21:45:56.229000000          42.675035
#
#           assignment5_submission  assignment6_grade  \
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 6  2016-03-19 10:35:41.869000000          45.359349
# 7  2016-02-16 14:22:23.664000000          65.266633
# 9  2016-03-27 15:55:04.414000000          38.407532
#
#           assignment6_submission
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 6  2016-03-23 14:02:00.987000000
# 7  2016-02-18 08:35:04.796000000
# 9  2016-03-30 20:33:13.554000000

# %%
late_finishers.shape
# Out:
# (1056, 13)

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024303
# 74.0450648477065

# %% [markdown]
# Ok, these look pretty similar. But, are they the same? What do we mean by similar? This is where the students' t-test comes in. It allows us to form the alternative hypothesis ("These are different") as well as the null hypothesis ("These are the same") and then test that null hypothesis.  When doing hypothesis testing, we have to choose a significance level as a threshold for how much of a chance we're willing to accept. This significance level is typically called alpha. For this example, let's use a threshold of 0.05 for our alpha or 5%. Now this is a commonly used number but it's really quite arbitrary.  The SciPy library contains a number of different statistical tests and forms a basis for hypothesis testing in Python and we're going to use the ttest_ind() function which does an independent t-test (meaning the populations are not related to one another). The result of ttest_index() are the t-statistic and a p-value. It's this latter value, the probability, which is most important to us, as it indicates the chance (between 0 and 1) of our null hypothesis being True.

# %%
# Let's bring in our ttest_ind function
from scipy.stats import ttest_ind

# Let's run this function with our two populations, looking at the assignment 1 grades
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.322354085372139, pvalue=0.1861810110171455)

# %% [markdown]
# So here we see that the probability is 0.18, and this is above our alpha value of 0.05. This means that we cannot reject the null hypothesis. The null hypothesis was that the two populations are the same, and we don't have enough certainty in our evidence (because it is greater than alpha) to come to a conclusion to the contrary. This doesn't mean that we have proven the populations are the same.

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %% [markdown]
# Ok, so it looks like in this data we do not have enough evidence to suggest the populations differ with respect to grade. Let's take a look at those p-values for a moment though, because they are saying things that can inform experimental design down the road. For instance, one of the assignments, assignment 3, has a p-value around 0.1. This means that if we accepted a level of chance similarity of 11% this would have been considered statistically significant. As a research, this would suggest to me that there is something here worth considering following up on. For instance, if we had a small number of participants (we don't) or if there was something unique about this assignment as it relates to our experiment (whatever it was) then there may be followup experiments we could run.

# %%
print(ttest_ind(early_finishers['assignment1_grade'], early_finishers['assignment1_grade']))
# Out:
# Ttest_indResult(statistic=0.0, pvalue=1.0)

# %% [markdown]
# P-values have come under fire recently for being insuficient for telling us enough about the interactions which are happening, and two other techniques, confidence intervalues and bayesian analyses, are being used more regularly. One issue with p-values is that as you run more tests you are likely to get a value which is statistically significant just by chance. Lets see a simulation of this. First, lets create a data frame of 100 columns, each with 100 numbers

# %%
df1 = pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.221452  0.478651  0.521055  0.653165  0.479053  0.435263  0.311085
# 1  0.359523  0.417974  0.700005  0.641604  0.158618  0.418617  0.045775
# 2  0.773406  0.830779  0.477130  0.811728  0.447763  0.650372  0.331460
# 3  0.682083  0.300571  0.434676  0.673405  0.249988  0.520477  0.033481
# 4  0.779109  0.609656  0.584169  0.970761  0.881193  0.952702  0.397944
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.403081  0.418804  0.086557  ...  0.788648  0.705975  0.842279  0.350025
# 1  0.577285  0.015873  0.276847  ...  0.996327  0.124228  0.304120  0.852934
# 2  0.598467  0.357043  0.754844  ...  0.400488  0.293846  0.795132  0.819577
# 3  0.055523  0.316269  0.330418  ...  0.311228  0.180681  0.367770  0.222080
# 4  0.705289  0.567753  0.761930  ...  0.615958  0.889344  0.076961  0.239032
#
#          94        95        96        97        98        99
# 0  0.609571  0.793392  0.894431  0.664283  0.789036  0.186932
# 1  0.960475  0.481115  0.730303  0.907904  0.374842  0.162419
# 2  0.604662  0.865844  0.218583  0.731883  0.143930  0.169845
# 3  0.102069  0.559394  0.920476  0.191557  0.300281  0.179856
# 4  0.352013  0.715696  0.173988  0.320731  0.212873  0.740818
#
# [5 rows x 100 columns]

# %%
df2 = pd.DataFrame([np.random.random(100) for x in range(100)])
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.635657  0.182528  0.596988  0.039955  0.119214  0.132137  0.883967
# 1  0.199336  0.767676  0.576099  0.654235  0.157193  0.626929  0.598582
# 2  0.655089  0.363204  0.639567  0.806922  0.071888  0.322270  0.406999
# 3  0.783878  0.124703  0.038246  0.797945  0.476767  0.491464  0.672934
# 4  0.043826  0.239061  0.694119  0.440358  0.065531  0.764984  0.354549
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.736176  0.863172  0.352351  ...  0.283568  0.860838  0.669368  0.157269
# 1  0.083822  0.270944  0.688214  ...  0.440801  0.308682  0.159191  0.019996
# 2  0.232438  0.419471  0.718685  ...  0.127344  0.664537  0.821137  0.625833
# 3  0.010226  0.510626  0.534995  ...  0.909539  0.092671  0.071289  0.893724
# 4  0.164276  0.488101  0.443035  ...  0.557233  0.006086  0.455456  0.085190
#
#          94        95        96        97        98        99
# 0  0.180762  0.554046  0.035545  0.569552  0.588088  0.214956
# 1  0.466058  0.091275  0.751510  0.976436  0.324459  0.474164
# 2  0.537020  0.547613  0.457943  0.875424  0.776509  0.509397
# 3  0.567123  0.209523  0.773770  0.530695  0.054186  0.165794
# 4  0.904183  0.701973  0.581135  0.691418  0.811140  0.470397
#
# [5 rows x 100 columns]

# %% [markdown]
# Are these two DataFrames the same? Maybe a better question is, for a given row inside of df1, is it the same as the row inside df2? Let's take a look. Let's say our critical value is 0.1, or and alpha of 10%. And we're going to compare each column in df1 to the same numbered column in df2. And we'll report when the p-value isn't less than 10%, which means that we have sufficient evidence to say that the columns are different.

# %%
def test_column(alpha=0.1):
    num_diff=0
    for col in df1.columns:
        teststat, pval = ttest_ind(df1[col], df2[col])
        if pval<=alpha:
            print('Col {} is statistically significantly different at alpha={}, pval={}'.format(col,alpha,pval))
            num_diff+=1
    print("Total number different was {}, which is {}%".format(num_diff,float(num_diff)/len(df1.columns)*100))
    
test_column()
# Out:
# Col 6 is statistically significantly different at alpha=0.1, pval=0.025563776953398405
# Col 37 is statistically significantly different at alpha=0.1, pval=0.004908796955795252
# Col 50 is statistically significantly different at alpha=0.1, pval=0.02959994333249068
# Col 52 is statistically significantly different at alpha=0.1, pval=0.09164451908183323
# Col 71 is statistically significantly different at alpha=0.1, pval=0.04117891560016706
# Col 73 is statistically significantly different at alpha=0.1, pval=0.01337862913404817
# Col 75 is statistically significantly different at alpha=0.1, pval=0.0892066302888323
# Col 87 is statistically significantly different at alpha=0.1, pval=0.03240907632852115
# Col 94 is statistically significantly different at alpha=0.1, pval=0.022876513594439905
# Col 95 is statistically significantly different at alpha=0.1, pval=0.015850342273716577
# Total number different was 10, which is 10.0%

# %%
test_column(0.05)
# Out:
# Col 6 is statistically significantly different at alpha=0.05, pval=0.025563776953398405
# Col 37 is statistically significantly different at alpha=0.05, pval=0.004908796955795252
# Col 50 is statistically significantly different at alpha=0.05, pval=0.02959994333249068
# Col 71 is statistically significantly different at alpha=0.05, pval=0.04117891560016706
# Col 73 is statistically significantly different at alpha=0.05, pval=0.01337862913404817
# Col 87 is statistically significantly different at alpha=0.05, pval=0.03240907632852115
# Col 94 is statistically significantly different at alpha=0.05, pval=0.022876513594439905
# Col 95 is statistically significantly different at alpha=0.05, pval=0.015850342273716577
# Total number different was 8, which is 8.0%

# %%
df2=pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
test_column()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=0.0001443169356067365
# Col 1 is statistically significantly different at alpha=0.1, pval=3.0938073900894635e-05
# Col 2 is statistically significantly different at alpha=0.1, pval=4.601049725028687e-05
# Col 3 is statistically significantly different at alpha=0.1, pval=0.0005972141191740876
# Col 4 is statistically significantly different at alpha=0.1, pval=0.02911415657091566
# Col 5 is statistically significantly different at alpha=0.1, pval=0.00019419192631704848
# Col 6 is statistically significantly different at alpha=0.1, pval=0.0005903490154332418
# Col 7 is statistically significantly different at alpha=0.1, pval=7.97431225508124e-05
# Col 8 is statistically significantly different at alpha=0.1, pval=0.00015426472178808678
# Col 9 is statistically significantly different at alpha=0.1, pval=0.003251586291974789
# Col 10 is statistically significantly different at alpha=0.1, pval=0.005242898835195929
# Col 11 is statistically significantly different at alpha=0.1, pval=2.618467913733588e-05
# Col 12 is statistically significantly different at alpha=0.1, pval=0.0008983898940503326
# Col 13 is statistically significantly different at alpha=0.1, pval=0.01607860574043728
# Col 14 is statistically significantly different at alpha=0.1, pval=0.0004807896069533748
# Col 15 is statistically significantly different at alpha=0.1, pval=0.005889364851133371
# Col 16 is statistically significantly different at alpha=0.1, pval=0.0006041390086179154
# Col 17 is statistically significantly different at alpha=0.1, pval=0.00010467633365457275
# Col 18 is statistically significantly different at alpha=0.1, pval=0.0021412857425823473
# Col 19 is statistically significantly different at alpha=0.1, pval=0.00020791388506224268
# Col 20 is statistically significantly different at alpha=0.1, pval=0.00018487449354383573
# Col 21 is statistically significantly different at alpha=0.1, pval=0.026937671453085725
# Col 22 is statistically significantly different at alpha=0.1, pval=0.009134150761143118
# Col 23 is statistically significantly different at alpha=0.1, pval=0.0009358623935819902
# Col 24 is statistically significantly different at alpha=0.1, pval=0.0012106807603065426
# Col 25 is statistically significantly different at alpha=0.1, pval=0.005695348871593304
# Col 26 is statistically significantly different at alpha=0.1, pval=0.001040122119353463
# Col 27 is statistically significantly different at alpha=0.1, pval=0.007969669180238137
# Col 28 is statistically significantly different at alpha=0.1, pval=0.000514141771401711
# Col 29 is statistically significantly different at alpha=0.1, pval=0.00045650435027598616
# Col 30 is statistically significantly different at alpha=0.1, pval=0.00687251302033755
# Col 31 is statistically significantly different at alpha=0.1, pval=0.005206363815303666
# Col 32 is statistically significantly different at alpha=0.1, pval=0.0023704031144570568
# Col 33 is statistically significantly different at alpha=0.1, pval=2.223866903741262e-06
# Col 34 is statistically significantly different at alpha=0.1, pval=0.0019467144676240014
# Col 35 is statistically significantly different at alpha=0.1, pval=0.0025818538096877273
# Col 36 is statistically significantly different at alpha=0.1, pval=2.2205053118662628e-06
# Col 37 is statistically significantly different at alpha=0.1, pval=0.0002566392150935248
# Col 38 is statistically significantly different at alpha=0.1, pval=0.0006121398200353837
# Col 39 is statistically significantly different at alpha=0.1, pval=0.010361714239696175
# Col 40 is statistically significantly different at alpha=0.1, pval=5.364251950155767e-06
# Col 41 is statistically significantly different at alpha=0.1, pval=0.0017109453592436942
# Col 42 is statistically significantly different at alpha=0.1, pval=6.177059372793886e-05
# Col 43 is statistically significantly different at alpha=0.1, pval=0.00048095151352463874
# Col 44 is statistically significantly different at alpha=0.1, pval=0.0006283853779185712
# Col 45 is statistically significantly different at alpha=0.1, pval=0.03250735009875222
# Col 46 is statistically significantly different at alpha=0.1, pval=0.00014032935384344748
# Col 47 is statistically significantly different at alpha=0.1, pval=0.0006579346021148698
# Col 48 is statistically significantly different at alpha=0.1, pval=0.001523160274365677
# Col 49 is statistically significantly different at alpha=0.1, pval=0.001126064501260498
# Col 50 is statistically significantly different at alpha=0.1, pval=0.01027568394306259
# Col 51 is statistically significantly different at alpha=0.1, pval=0.0005501467828236471
# Col 52 is statistically significantly different at alpha=0.1, pval=0.007344409078254875
# Col 53 is statistically significantly different at alpha=0.1, pval=0.00017962878676691966
# Col 54 is statistically significantly different at alpha=0.1, pval=0.0004982997288478249
# Col 55 is statistically significantly different at alpha=0.1, pval=5.849532328337079e-06
# Col 56 is statistically significantly different at alpha=0.1, pval=0.00015122578166601162
# Col 57 is statistically significantly different at alpha=0.1, pval=0.00916806915548046
# Col 58 is statistically significantly different at alpha=0.1, pval=0.0026886200942043068
# Col 59 is statistically significantly different at alpha=0.1, pval=2.7277867492886807e-06
# Col 60 is statistically significantly different at alpha=0.1, pval=0.006547793653225525
# Col 61 is statistically significantly different at alpha=0.1, pval=0.00031884623633958637
# Col 62 is statistically significantly different at alpha=0.1, pval=0.07730829640667236
# Col 63 is statistically significantly different at alpha=0.1, pval=2.4818101181591438e-05
# Col 64 is statistically significantly different at alpha=0.1, pval=0.002869269763888259
# Col 65 is statistically significantly different at alpha=0.1, pval=4.49130126127334e-05
# Col 66 is statistically significantly different at alpha=0.1, pval=0.04197757582134779
# Col 67 is statistically significantly different at alpha=0.1, pval=0.00013477623748719172
# Col 68 is statistically significantly different at alpha=0.1, pval=0.0038515165713248734
# Col 69 is statistically significantly different at alpha=0.1, pval=0.00031954003610274817
# Col 70 is statistically significantly different at alpha=0.1, pval=0.0005796247184575623
# Col 71 is statistically significantly different at alpha=0.1, pval=0.0015634198540347452
# Col 72 is statistically significantly different at alpha=0.1, pval=9.994727644805028e-05
# Col 73 is statistically significantly different at alpha=0.1, pval=5.276602220448822e-06
# Col 74 is statistically significantly different at alpha=0.1, pval=1.2931471839882576e-06
# Col 75 is statistically significantly different at alpha=0.1, pval=2.737732610441956e-07
# Col 76 is statistically significantly different at alpha=0.1, pval=0.00035366344161422565
# Col 77 is statistically significantly different at alpha=0.1, pval=0.0003906568403672248
# Col 78 is statistically significantly different at alpha=0.1, pval=0.0024953808089756514
# Col 79 is statistically significantly different at alpha=0.1, pval=0.0002991636862384861
# Col 80 is statistically significantly different at alpha=0.1, pval=0.00018193818983041715
# Col 81 is statistically significantly different at alpha=0.1, pval=0.0002676682273959216
# Col 82 is statistically significantly different at alpha=0.1, pval=0.0001239981417249933
# Col 83 is statistically significantly different at alpha=0.1, pval=0.00030875524687708347
# Col 84 is statistically significantly different at alpha=0.1, pval=0.005636633164102968
# Col 85 is statistically significantly different at alpha=0.1, pval=0.00442758632606428
# Col 86 is statistically significantly different at alpha=0.1, pval=0.0011658553263897305
# Col 87 is statistically significantly different at alpha=0.1, pval=1.4119146163516193e-05
# Col 88 is statistically significantly different at alpha=0.1, pval=0.006765202763178445
# Col 89 is statistically significantly different at alpha=0.1, pval=0.0025490426138677206
# Col 90 is statistically significantly different at alpha=0.1, pval=0.00015382677680052665
# Col 91 is statistically significantly different at alpha=0.1, pval=0.00028912341765694697
# Col 92 is statistically significantly different at alpha=0.1, pval=0.01715123783442678
# Col 93 is statistically significantly different at alpha=0.1, pval=0.00015776844515160205
# Col 94 is statistically significantly different at alpha=0.1, pval=0.0023255352322222125
# Col 95 is statistically significantly different at alpha=0.1, pval=0.015164993988035435
# Col 96 is statistically significantly different at alpha=0.1, pval=5.565523119110578e-06
# Col 97 is statistically significantly different at alpha=0.1, pval=0.0024872147119549205
# Col 98 is statistically significantly different at alpha=0.1, pval=0.0020364678245282973
# Col 99 is statistically significantly different at alpha=0.1, pval=0.013996191017680055
# Total number different was 100, which is 100.0%
