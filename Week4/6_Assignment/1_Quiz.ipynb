# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# Q1. Consider the given NumPy arrays a and b. What will be the value of c after the following code is executed?

# %%
a = np.arange(8)
b = a[4:6]
b[:] = 40
c = a[4] + a[6]
c
# Out:
# 46

# %%
a
# Out:
# array([ 0,  1,  2,  3, 40, 40,  6,  7])

# %% [markdown]
# Q2. Given the string s as shown below, which of the following expressions will be True?

# %%
s = 'ABCAC'
re.match('A', s) == True
# Out:
# False

# %%
re.match('A', s)
# Out:
# <re.Match object; span=(0, 1), match='A'>

# %%
bool(re.match('A', s)) == True
# Out:
# True

# %%
len(re.split('A', s)) == 2
# Out:
# False

# %%
len(re.split('A', s))
# Out:
# 3

# %%
re.search('A', s)
# Out:
# <re.Match object; span=(0, 1), match='A'>

# %% [markdown]
# Q3. Consider a string s. We want to find all characters (other than A) which are followed by triple A, i.e., have AAA to the right. We don’t want to include the triple A in the output and just want the character immediately preceding AAA . Complete the code given below that would output the required result.

# %%
def result():
    s = 'ACAABAACAAABACDBADDDFSDDDFFSSSASDAFAAACBAAAFASD'

    result = []
    # compete the pattern below
    pattern = '(.)(AAA)'
    # pattern = '(.)(?=AAA)'
    for item in re.finditer(pattern, s):
      # identify the group number below.
      result.append(item.group(1))
      
    return result

result()
# Out:
# ['C', 'F', 'B']

# %% [markdown]
# Q4. Consider the following 4 expressions regarding the above pandas Series df. All of them have the same value except one expression. Can you identify which one it is?

# %%
df = pd.Series([4, 7, -5, 3], index=list('dbac'))
df
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
df[0]
# Out:
# 4

# %%
df.index[0]
# Out:
# 'd'

# %%
df['d']
# Out:
# 4

# %%
df.iloc[0]
# Out:
# 4

# %% [markdown]
# Q5. Consider the two pandas Series objects shown below, representing the no. of items of different yogurt flavors that were sold in a day from two different stores, s1 and s2. Which of the following statements is True regarding the Series s3 defined below?

# %%
s1 = pd.Series([20, 15, 18, 31], index = ['Mango', 'Strawberry', 'Blueberry', 'Vanilla'])
s2 = pd.Series([20, 30, 15, 20, 20], 
               index = ['Strawberry', 'Vanilla', 'Banana' ,'Mango', 'Plain'])
s3 = s1.add(s2)

# %%
s1
# Out:
# Mango         20
# Strawberry    15
# Blueberry     18
# Vanilla       31
# dtype: int64

# %%
s2
# Out:
# Strawberry    20
# Vanilla       30
# Banana        15
# Mango         20
# Plain         20
# dtype: int64

# %%
s3
# Out:
# Banana         NaN
# Blueberry      NaN
# Mango         40.0
# Plain          NaN
# Strawberry    35.0
# Vanilla       61.0
# dtype: float64

# %%
s3['Mango'] >=  s1.add(s2, fill_value = 0)['Mango']
# Out:
# True

# %% [markdown]
# Q6. In the following list of statements regarding a DataFrame df, one or more statements are correct. Can you identify all the correct statements?
# ![image.png](attachment:image.png)

# %% [markdown]
# Q7. Consider the Series object S defined below. Which of the following is an incorrect way to slice S such that we obtain all data points corresponding to the indices 'b', 'c', and 'd'?

# %%
S = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
S
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
S[['b', 'c', 'd']]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
S[S <= 3][S > 0]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S > 0
# Out:
# a    False
# b     True
# c     True
# d     True
# e     True
# dtype: bool

# %%
S <= 3
# Out:
# a     True
# b     True
# c     True
# d     True
# e    False
# dtype: bool

# %%
S[1:4]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %% [markdown]
# Q8. Consider the DataFrame df shown below with indexes 'R1', 'R2', 'R3', and 'R4'.  In the following code, a new DataFrame df_new is created using df. What will be the value of df_new[1] after the below code is executed?

# %%
df = pd.DataFrame([[5, 6, 20], [5, 82, 28], [71, 31, 92], [67, 37, 49]], 
                  index=['R1', 'R2', 'R3', 'R4'],
                  columns=list('abc'))
df
# Out:
#      a   b   c
# R1   5   6  20
# R2   5  82  28
# R3  71  31  92
# R4  67  37  49

# %%
f = lambda x: x.max() + x.min()
df_new = df.apply(f)
df_new
# Out:
# a     76
# b     88
# c    112
# dtype: int64

# %%
df_new[1]
# Out:
# 88

# %% [markdown]
# Q9. ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# **Correct -**
# + new_df.unstack().unstack()
# When we unstack the new_df first time, we will get a Series with triple row index, when we unstack this Series again, the inner most row, which is actually the previous country, will be moved to the column index again.
#
# **Incorrect -**
# + new_df.stack()
# When we stack the new_df, we will move the lowermost column to the inner most row. So we will get a dataframe with multiple index 'country' and 'Rank_Level'.
#
#
# + new_df.unstack()
# When we unstack the new_df, we will move the inner most row to the lowermost column, as a result, we will have no index in the row, and get a Series.
#
#
# + new_df.stack().stack()
# When we stack the new_df twice, we will move both two column index to row, as a result, we will get a Series.

# %% [markdown]
# Q10. Consider the DataFrame df shown below. What will be the output (rounded to the nearest integer) when the following code related to df is executed:

# %%
df = pd.DataFrame({'Item' : ['item1']*3 + ['item2']*3,
                   'Store' : ['A', 'B', 'C']*2,
                   'Quantity sold' : [10, 20, np.nan, 5, 10, 15]})
df
# Out:
#     Item Store  Quantity sold
# 0  item1     A           10.0
# 1  item1     B           20.0
# 2  item1     C            NaN
# 3  item2     A            5.0
# 4  item2     B           10.0
# 5  item2     C           15.0

# %%
df.groupby('Item').sum().iloc[0]['Quantity sold']
# Out:
# 30.0

# %%
df.groupby('Item').sum()
# Out:
#        Quantity sold
# Item
# item1           30.0
# item2           30.0

# %%
df.groupby('Item').sum().iloc[0]
# Out:
# Quantity sold    30.0
# Name: item1, dtype: float64

# %%
df.groupby('Item').sum().iloc[0]['Quantity sold']
# Out:
# 30.0
